# %%
import pprint
import pandas as pd
import os
import json
import numpy as np
import seaborn
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
seaborn.set_style('whitegrid')

# %%
os.chdir('/Users/franciscojavierarceo/Tmp/')

# %%
def buildCDF(df, var):
    cdf = pd.DataFrame(df[var].value_counts())
    cdf = cdf.reset_index(drop=False)
    cdf.columns = [var, 'count']
    cdf['percent'] = cdf['count'] / cdf['count'].sum()
    cdf = cdf.sort_values(by=var)
    cdf['cumpercent'] = cdf['percent'].cumsum()
    return cdf

# %%
input_file = open('./app-timers.json')
data = input_file.readlines()
out = []
for row in data:
    out.append(json.loads(row.replace("\n",'')))

fin = pd.read_json(json.dumps(out))
fin.columns = [l.replace("Timer", "") for l in fin.columns.tolist()]

# %%
v1 = fin[fin['$app_release']=='3.1.11-PRD'].describe().T
v2 = fin[fin['$app_release']=='3.1.12-PRD'].describe().T 
v1.columns = ['v11_'+l for l in  v1.columns.tolist()]
v2.columns = ['v12_'+l for l in  v2.columns.tolist()]
summary = pd.concat([v1, v2], axis=1)
rc = [(x,y,v.replace("v12_",'')) for x,y,v in zip(v1.columns.tolist(), v2.columns.tolist(), v2.columns.tolist())]
for x,y,z in rc:
    summary[z + 'ratio'] = summary[y] / summary[x]

# %%
xvar = 'countratio'
summary = summary.sort_values(xvar)
summary[xvar].plot(kind='barh', figsize=(15, 12), title='%s of new/old - if > 1 then longer' % xvar)
plt.axvline(x=1, c='red')
plt.show()

# %%
plotvars = [l for l in summary.columns if 'ratio' in l and '%' not in l]

# %% [markdown]
# This is an example of a real data science project we've worked on at Hinge a while back.  We instrumented a beta version of our app with timers for various in-app events, such as loading a profile or resuming from sleep.
#
# ## We want to know which operations are slowest so we can decide where to focus our efforts.
#
# ## The goal is to easily let people see what's taking time in the app, and provide feedback on our improvements over time.
#
# The data is a sequence of JSON objects giving information about the duration of one or more in-app events.  Each record has a timestamp, app version, and some event timings.  Hopefully, with each version we are making improvements and the app is getting better over time.
#
# ## For this project, your goal is to provide a visualization to show what's slow and how that might be changing.
#
# The exact way you do this is up to you: use your data science, statistics, and infoviz skills to make it easy for people to monitor app performance at a glance.  The presentation should be intuitive but does not need to be polished or pretty.
#
# The attached data is proprietary and confidential; please do not share it with anyone, and please do not post the results on the public Internet.

# %%
# Note: new / old >>>> If > 1 then slower
summary[['v11_mean','v12_mean', 'meanratio']]
# Out:
#                                           v11_mean      v12_mean  meanratio
# ProfileCarouselPhotoDownloadTime      4.236170e-01           NaN        NaN
# ProfileCarouselPhotoCropTime          7.159158e-01           NaN        NaN
# AppLaunchPubNub                       5.790000e-01  4.855000e-01   0.838515
# MatchProfileCoverPhotoLoadTime        5.498871e-01  6.214583e-01   1.130156
# RegistrationLoadingCarouselDuration   2.345368e+02  2.942730e+02   1.254699
# MatchProfileFirstPhotoLoadTime        1.399451e+00  3.285714e-02   0.023479
# AppLaunchDownloadingMatches           8.851367e+00  3.768942e+00   0.425803
# PotentialProfileFirstPhotoLoadTime    2.607562e-01  2.028350e-01   0.777872
# PotentialProfileCoverPhotoLoadTime    9.021605e-01  6.231826e-01   0.690767
# AppLaunchDownloadingFBGraphUser       6.137018e-01  3.612759e-01   0.588683
# AppLaunchDownloadingApiVersion        1.264979e+00  1.201788e+00   0.950046
# AppLaunchDownloadingPotentials        1.072067e+00  1.428000e+00   1.332007
# AppResumeVisible                      4.719242e+00  7.770848e+00   1.646630
# BatchPhotoLoadTime                    1.497800e-01  3.103444e-01   2.072002
# MutualFriendPhotoLoadTime             4.463622e-01  2.685218e-01   0.601578
# MatchProfileDetailsVisible            7.105221e-02  7.614050e-02   1.071613
# time                                  1.415899e+09  1.415715e+09   0.999870
# MatchProfileShellVisible              5.581455e-02  5.950896e-02   1.066191
# MatchProfileFullyVisible              5.765328e-01  4.769604e-01   0.827291
# AppLaunchDownloading                  1.254171e+01  8.922209e+00   0.711403
# AppLaunchRendering                    4.609340e+00  8.867283e-01   0.192376
# PotentialProfileFullyVisible          4.034044e-01  4.289659e-01   1.063364
# PotentialProfileShellVisible          6.396703e-02  6.999109e-02   1.094174
# ProfileCarouselPhotoLoadTime          7.119690e-01  5.648793e-01   0.793404
# AppLaunchVisible                      1.843648e+02  5.421763e+02   2.940780
# ProfileCarouselPhotoGetFromCacheTime  6.626831e-01  4.760505e-01   0.718368
# AppLaunchStartup                      1.015306e-01  9.003333e-02   0.886760
# AppLaunchInitializing                 1.009898e+00  1.043776e+00   1.033546
# PotentialProfileDetailsVisible        6.256061e-02  6.408633e-02   1.024388
# ProfileCoverPhotoLoadTime             7.472736e-01  6.822123e-01   0.912935
# ProfileFirstPhotoLoadTime             8.588494e-01  3.298903e-01   0.384107

# %%
def plotTime(df, xvar):
    t1 = pd.DataFrame(df.ix[df['$app_release']=='3.1.11-PRD', xvar]).reset_index(drop=True)
    t2 = pd.DataFrame(df.ix[df['$app_release']=='3.1.12-PRD', xvar]).reset_index(drop=True)

    t1['time'] = df.ix[df['$app_release']=='3.1.11-PRD', 'time'].values
    t2['time'] = df.ix[df['$app_release']=='3.1.12-PRD', 'time'].values
    t1gx1 = t1[t1[xvar].notnull()].groupby(['time']).count()
    t2gx1 = t2[t2[xvar].notnull()].groupby(['time']).count()

    plt.figure(figsize=(12, 8))
    plt.plot(t1gx1.index, t1gx1[xvar], c='blue', label='App Version 1')
    plt.plot(t2gx1.index, t2gx1[xvar], c='red', label='App Version 2')
    plt.title("%s across time" % xvar)
    plt.legend()
    plt.show()

def plotData(df, xvar):
    t1 = pd.DataFrame(df.ix[df['$app_release']=='3.1.11-PRD', xvar]).reset_index(drop=True)
    t2 = pd.DataFrame(df.ix[df['$app_release']=='3.1.12-PRD', xvar]).reset_index(drop=True)
    cdf1 = buildCDF(t1[t1[xvar].notnull()], xvar)
    cdf2 = buildCDF(t2[t2[xvar].notnull()], xvar)
    mdf = pd.concat([pd.value_counts(t1[xvar].isnull(), normalize=True), 
                     pd.value_counts(t2[xvar].isnull(), normalize=True)], 
                    axis=1)
    mdf.columns = ['App Version 1', 'App Version 2']
    f, axarr = plt.subplots(1, 3, figsize=(16,8))
    axarr[0].bar(np.arange(2), mdf.values[0,:], width=-0.5, align='center')
    axarr[0].set_xticks(np.arange(2))
    axarr[0].set_xticklabels(mdf.columns.tolist())
    axarr[0].set_ylabel('Missingness')
    axarr[0].set_title('Percent Missing by App Version')
    axarr[0].set_ylim([0, 1])
    axarr[1].plot(cdf1[xvar], cdf1['cumpercent'], label='App Version 1', c='blue')
    axarr[1].plot(cdf2[xvar], cdf2['cumpercent'], label='App Version 2', c='red')
    axarr[1].set_xlabel('Profile First Photo Load Time')
    axarr[1].set_ylim([0, 1])
    axarr[1].legend()
    axarr[1].grid()
    axarr[1].set_title('Cumulative Percent of Load Time')
    axarr[2].hist([t1.ix[t1[xvar].notnull(), xvar], t2.ix[t2[xvar].notnull(), xvar]], color=['r','b'])    
    axarr[2].grid()
    f.suptitle(xvar, fontsize=24, y=1.05)

    f.tight_layout()
    f.show()

# %%
for xvar in summary.index.tolist():
    if xvar != 'time':
        plotTime(fin, xvar)

# %%
for xvar in summary.index.tolist():
    if xvar != 'time':
        plotData(fin, xvar)
