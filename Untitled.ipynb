# %%
import pprint
import pandas as pd
import os
import json
import numpy as np
import seaborn
from matplotlib import pyplot as plt

from __future__ import print_function
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %matplotlib inline
seaborn.set_style('whitegrid')
# Out:
# /Users/franciscojavierarceo/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
os.chdir('/Users/franciscojavierarceo/Tmp/')

# %%
def buildCDF(df, xvar):
    """
    Parameters 
    ----- 
    df:     pandas.DataFrame : Input data frame
    xvar:   string           : Variable of interest to create cumulative distribution function
    
    Output
    -----
    Data-frame summarizing the cumulative percent of the input variable
    """ 
    cdf = pd.DataFrame(df[xvar].value_counts())
    cdf = cdf.reset_index(drop=False)
    cdf.columns = [xvar, 'count']
    cdf['percent'] = cdf['count'] / cdf['count'].sum()
    cdf = cdf.sort_values(by=xvar)
    cdf['cumpercent'] = cdf['percent'].cumsum()
    return cdf

def plotData(df, xvar, metric):
    """
    Parameters 
    ----- 
    df:     pandas.DataFrame : Input data frame of cleaned data
    xvar:   string           : Variable of interest to plot
    metric: string           : Metric of aggregation to plot for the time series graph
    
    Output
    -----
    4 unique plots showing different summary statistics of the input variable
    """   
    t1 = pd.DataFrame(df.ix[df['$app_release']=='3.1.11-PRD', xvar]).reset_index(drop=True)
    t2 = pd.DataFrame(df.ix[df['$app_release']=='3.1.12-PRD', xvar]).reset_index(drop=True)
    t1['time'] = df.ix[df['$app_release']=='3.1.11-PRD', 'time'].values
    t2['time'] = df.ix[df['$app_release']=='3.1.12-PRD', 'time'].values
    
    # This creates the aggregations across time
    t1gx1 = t1[t1[xvar].notnull()].groupby(['time']).agg(metric)
    t2gx1 = t2[t2[xvar].notnull()].groupby(['time']).agg(metric)

    # Looking at the cumulative distribution for non-missing
    cdf1 = buildCDF(t1[t1[xvar].notnull()], xvar)
    cdf2 = buildCDF(t2[t2[xvar].notnull()], xvar)
    meanchange = (t2.ix[t2[xvar].notnull(), xvar].mean() / t1.ix[t1[xvar].notnull(), xvar].mean()) - 1.
    mdnchange = (t2.ix[t2[xvar].notnull(), xvar].median() / t1.ix[t1[xvar].notnull(), xvar].median()) - 1.

    print("For %s the new app saw an average relative change of %.3f " % (xvar, meanchange) )
    print("For %s the new app saw a median relative change of %.3f " % (xvar, mdnchange) )
    mdf = pd.concat([pd.value_counts(t1[xvar].isnull(), normalize=True), 
                     pd.value_counts(t2[xvar].isnull(), normalize=True)], 
                    axis=1)
    mdf.columns = ['App Version 1', 'App Version 2']
    f, axarr = plt.subplots(1, 3, figsize=(16,8))
    axarr[0].bar(np.arange(2), mdf.values[0,:], width=-0.5, align='center', color=['blue', 'red'])
    axarr[0].set_xticks(np.arange(2))
    axarr[0].set_xticklabels(mdf.columns.tolist())
    axarr[0].set_ylabel('Percent of Observations Missing')
    axarr[0].set_title('Missingness of %s by App Version' % xvar)
    axarr[0].set_ylim([0, 1])
    axarr[0].grid()
    axarr[0].legend()
    axarr[1].plot(cdf1[xvar], cdf1['cumpercent'], label='App Version 1', c='blue')
    axarr[1].plot(cdf2[xvar], cdf2['cumpercent'], label='App Version 2', c='red')
    axarr[1].set_xlabel(xvar)
    axarr[1].set_ylim([0, 1])
    axarr[1].legend()
    axarr[1].grid()
    axarr[1].set_title('Cumulative Percent of Load Time \n (Excluding Missing)')
    axarr[2].hist([t1.ix[t1[xvar].notnull(), xvar], t2.ix[t2[xvar].notnull(), xvar]],
                  color=['blue','red'], label=['App Version 1', 'App Version 2'])
    axarr[2].set_title('Histogram of %s \n (Excluding Missing)' % xvar)
    axarr[2].set_xlabel(xvar)
    axarr[2].legend()
    axarr[2].grid()
    f.suptitle("Summary of %s" % xvar, fontsize=24, y=1.05)
    f.tight_layout()
    f.show()

    plt.figure(figsize=(16, 8))
    plt.plot(t1gx1.index, t1gx1[xvar], c='blue', label='App Version 1')
    plt.plot(t2gx1.index, t2gx1[xvar], c='red', label='App Version 2')
    plt.title("%s of %s over time" % (metric, xvar) )
    plt.legend()
    plt.show()
    
def summarPlot(xvar, sdf):
    ttl = "Ratio of %s for new app / old app" % xvar.replace("ratio", "")
    sdf[xvar].plot(kind='barh', figsize=(15, 12), title=ttl)
    plt.axvline(x=1, c='red')
    plt.show()
    
def fSP(Variable):
    summarPlot(Variable, summary)
    
def f(Variable, Metric):
    plotData(fin, Variable, Metric)

# %% [markdown]
# # Cleaned up the data and reading it in

# %%
input_file = open('./app-timers.json')
data = input_file.readlines()
out = []
for row in data:
    out.append(json.loads(row.replace("\n",'')))

fin = pd.read_json(json.dumps(out))
fin.columns = [l.replace("Timer", "") for l in fin.columns.tolist()]
# Indexing the time variable to start at 0
# fin['time'] = fin['time'] - fin['time'].min()

# %% [markdown]
# # Summarizing the variables

# %%
v1 = fin[fin['$app_release']=='3.1.11-PRD'].describe().T
v2 = fin[fin['$app_release']=='3.1.12-PRD'].describe().T 

v1.columns = ['v11_'+l for l in  v1.columns.tolist()]
v2.columns = ['v12_'+l for l in  v2.columns.tolist()]

# The describe function contains useful summaries but it doesn't have medians so I'm adding them here
v1['v11_median'] = 0
for col in fin.columns:
    if col != '$app_release':
        v1.ix[v1.index==col,'v11_median']  = fin.ix[fin['$app_release']=='3.1.11-PRD', col].median(skipna=True)

v2['v12_median'] = 0
for col in fin.columns:
    if col != '$app_release':
        v2.ix[v2.index==col,'v12_median']  = fin.ix[fin['$app_release']=='3.1.12-PRD', col].median(skipna=True)

summary = pd.concat([v1, v2], axis=1)
rc = [(x, y, z.replace("v12_",'')) for x, y, z in zip(v1.columns, v2.columns, v2.columns)]

for x, y, z in rc:
    summary[z + 'ratio'] = summary[y] / summary[x]
    
# These are the Input variables for the widgets below
summaryvars = tuple(l for l in summary.columns if 'ratio' in l and '%' not in l)
inputvars = tuple(k for k in summary.index.tolist() if k!= 'time')
metric = ("mean", "count", "median")

# %%
# To do add plot of time by day hour

# %%
interact(fSP, Variable=summaryvars)

# %%
fin['day'] = [x[2:4] for x in fin['time'].astype(str)]
fin['hour'] = [(int(x[5:7])/99. * 23) for x in fin['time'].astype(str)]
fin['minute'] = [ int((int(x[1][0:2])/99.)*59) for x in fin['hour'].astype(str).str.split(".")]
fin['hour'] = [x[0] for x in fin['hour'].astype(str).str.split(".")]

# %%
fin[['time', 'day', 'hour', 'minute']].head()
# Out:
#          time day hour  minute
# 0  1415577710  15   17      52
# 1  1415577710  15   17      52
# 2  1415577710  15   17      52
# 3  1415577710  15   17      52
# 4  1415577710  15   17      52

# %%
interact(f, Variable=inputvars, Metric=metric)
# Out:
# For AppLaunchDownloading the new app saw an average relative change of -0.289
# For AppLaunchDownloading the new app saw a median relative change of 0.042
# <function __main__.f>

# %% [markdown]
# We instrumented a beta version of our app with timers for various in-app events, such as loading a profile or resuming from sleep.
#
# ## We want to know which operations are slowest so we can decide where to focus our efforts.
#
# ## The goal is to easily let people see what's taking time in the app, and provide feedback on our improvements over time.
#
# The data is a sequence of JSON objects giving information about the duration of one or more in-app events.  Each record has a timestamp, app version, and some event timings.  Hopefully, with each version we are making improvements and the app is getting better over time.
#
# ## For this project, your goal is to provide a visualization to show what's slow and how that might be changing.
#
# The exact way you do this is up to you: use your data science, statistics, and infoviz skills to make it easy for people to monitor app performance at a glance.  The presentation should be intuitive but does not need to be polished or pretty.
#
# The attached data is proprietary and confidential; please do not share it with anyone, and please do not post the results on the public Internet.
