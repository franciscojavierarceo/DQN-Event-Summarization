# %% [markdown]
# ### Each file contains four parts separated by ‘\n\n’. They are
#     1. url of the original article;
#     2. sentences in the article and their labels (for sentence-based extractive summarization);
#     3. extractable highlights (for word extraction-based abstractive summarization);
#     4. named entity mapping.
#
# ### Sentence labels. There are three labels for the sentences: 1, 2 and 0.
#
#     - 1: sentence should extracted;
#     - 2: sentence might be extracted;
#     - 0: sentence shouldn't be extracted.
#
# ### Extractable highlights
#
# The extractable highlights are created by examining if a word (or its morphological transformation) in the highlight appears in the article or a general purpose stop-word list, which together constitute the output space (i.e., the allowed vocabulary during summary generation).

# %%
import os
# import urllib2
from urllib.request import urlopen
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
def buildEntityDictionary(input_path, filenames):
    # Swapping in the entity names
    entitykey, entityname = [], []
    for filename in filenames:
        f = open(os.path.join(input_path, filename))
        data = f.read()
        entities = data.split("\n\n")[3]

        for entity in entities.split("\n"):
            entitykey.append( entity.split(":")[0] )
            entityname.append( entity.split(":")[1] )

    edictionary = dict(zip(entitykey, entityname))
    return edictionary    

def cleandata(input_path, files, edict):
    f = open(os.path.join(input_path, files))
    data = f.read()

    url  = data.split("\n\n")[0]
    article = data.split("\n\n")[1]
    nuggets = data.split("\n\n")[2]
    entities = data.split("\n\n")[3]

    # Parsing the sentences and substituting
    sentencelist, sentencelabel = [], []
    for sentence in article.split("\n"):
        # Swapping in the entity names
        sentencelabel.append(int(sentence.split("\t\t\t")[1]))
        sentence = sentence.split("\t\t\t")[0]
        newsentence = ' '.join([edict[word] if word in edict else word for word in sentence.split(" ")])
        sentencelist.append(newsentence)

    # Collecting the sentences in a list
    df = pd.DataFrame(sentencelist, columns=['Sentence'])
    df['Label'] = sentencelabel

    # Extracting the nuggets
    highlight = []
    for nugget in nuggets.split("\n"):
        newnugget = ' '.join([edict[word] if word in edict else word for word in nugget.split(" ")])
        highlight.append(newnugget)

    nuggets = pd.DataFrame(highlight, columns=['Nugget'])
    # Getting the title/query
#    html = requests.get(url).text
    html = urlopen(url).read()
    soup = BeautifulSoup(html, 'html.parser')
    try:
        title = soup.findAll("title")[0].text
    except:
        title = 'MISSING'
    return title, nuggets, df, df.shape[0]

# %%
# inputpath = '/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data/neuralsum/cnn/training/'
outputpath = '/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data2/0-output'
# datafiles = os.listdir(inputpath)

# %%
edict = buildEntityDictionary(inputpath, datafiles)

# %%
filelist = os.listdir(outputpath)
finished = [int(x.replace("q",'').replace("_stream.csv", '')) for x in filelist if 'stream.csv' in x]
finishedval = max(finished)
# outdf = pd.DataFrame(columns=['query_id','query','streamSize','query_filename', 'outfile_name', 'nuggetfilename'])

for i, datafile in enumerate(datafiles):
    if i > finishedval:
        query, nuggets, stream, streamSize = cleandata(inputpath, datafile, edict)
        outfilename = 'q%i_stream.csv' % i
        nuggetfilename = 'q%i_nuggets.csv' % i
        tmpdf = pd.DataFrame( [i, query, streamSize, datafile, outfilename, nuggetfilename] ).T
        tmpdf.columns = ['query_id','query','streamSize','query_filename', 'outfile_name', 'nuggetfilename']
        outdf = pd.concat([outdf, tmpdf], axis=0)
        stream.to_csv(os.path.join(outputpath, outfilename), index=False)
        nuggets.to_csv(os.path.join(outputpath, nuggetfilename), index=False)

# %%
outdf.to_csv("/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data2/1-output/cnn_trainingqueries.csv", 
             index=False, encoding='utf-8')

# %%
finalinputdir = '/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data2/0-output/'
finaloutputdir = '/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data2/1-output/'

finalinputfiles = os.listdir(finalinputdir)

# %% [markdown]
# # Validating the summaries

# %%
streams = [(int(x.split("_")[0].replace("q",'')), x) for x in finalinputfiles if '_stream.csv' in x]
nuggets = [(int(x.split("_")[0].replace("q",'')), x) for x in finalinputfiles if '_nuggets.csv' in x]

streamsummary = pd.DataFrame(streams, columns=['query_id','streamname'])
nuggetsummary = pd.DataFrame(nuggets, columns=['query_id','nuggetname'])

fulldf = pd.merge(streamsummary, nuggetsummary, how='inner', left_on = 'query_id', right_on='query_id')
dupes = outdf.drop_duplicates(inplace=False)['query_id'].value_counts().reset_index()
dupes.columns = ['query_id', 'count']
dupes = dupes[dupes['count'] > 1]
dedupefilter = outdf['query_id'].isin(dupes['query_id'])==False

# %%
# Exporting files
outdf[dedupefilter].to_csv(
    "/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data2/1-output/cnn_trainingqueries.csv", 
             index=False, encoding='utf-8')

# %%
outdf.shape[0], outdf[dedupefilter]['streamSize'].sum()
# Out:
# (85198, 2541426)

# %%
outdf[dedupefilter]['streamSize'].sum() / float(outdf.shape[0])
# Out:
# 29.829643888354187

# %% [markdown]
# # Reading data back in

# %%
import os
import urllib2
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
finalinputdir = '/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data2/0-output/'
finaloutputdir = '/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data2/1-output/'

finalinputfiles = os.listdir(finalinputdir)

# %%
outdf = pd.read_csv("/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data2/1-output/cnn_trainingqueries.csv")

# %%
def extract_data(inputdir, odf_row):
        cleanedstreams = pd.read_csv(inputdir + odf_row['outfile_name'])
        cleanedstreams['query'] = odf_row['query'].replace(" - CNN.com", "")
        cleanedstreams['query_id'] = odf_row['query_id']
        cleanedstreams['true_summary'] = ' '.join(cleanedstreams[cleanedstreams['Label']==1].Sentence)
        cleanedstreams['sentence_idx'] = cleanedstreams.index
        return cleanedstreams

# %%
from joblib import Parallel, delayed
streams = Parallel(n_jobs=-1)(
    delayed(extract_data)(finalinputdir, row) for i, row in outdf.iterrows()
)

# %%
cleanedstreams = pd.concat(streams)
cleanedstreams = cleanedstreams[['query_id', 'sentence_idx', 'Label','query','Sentence', 'true_summary']]
cleanedstreams.columns = [x.lower() for x in cleanedstreams.columns]

# %%
cleanedstreams.head()
# Out:
#    query_id  sentence_idx  label                                  query  \
# 0         0             0      1  Mistaken for your child's grandmother
# 1         0             1      1  Mistaken for your child's grandmother
# 2         0             2      1  Mistaken for your child's grandmother
# 3         0             3      1  Mistaken for your child's grandmother
# 4         0             4      2  Mistaken for your child's grandmother
#
#                                             sentence  \
# 0                       -- i 'm 45 , and my son is 7
# 1  once in a while , i still get carded when i tr...
# 2  i was 38 when Dominican Republic Emergency Ope...
# 3  both incidents took place after i moved from A...
# 4  i thought about the incidents when i read a re...
#
#                                         true_summary
# 0  -- i 'm 45 , and my son is 7 once in a while ,...
# 1  -- i 'm 45 , and my son is 7 once in a while ,...
# 2  -- i 'm 45 , and my son is 7 once in a while ,...
# 3  -- i 'm 45 , and my son is 7 once in a while ,...
# 4  -- i 'm 45 , and my son is 7 once in a while ,...

# %%
cleanedstreams.to_csv(
    "/Users/franciscojavierarceo/GitHub/DeepNLPQLearning/data2/1-output/cnn_trainingstreams.csv", 
             index=False, encoding='utf-8'
)

# %%
cleanedstreams.head()
# Out:
#     query_id  sentence_idx  label  \
# 0          0             0      1
# 1          0             1      1
# 2          0             2      1
# 3          0             3      1
# 4          0             4      2
# 5          0             5      2
# 6          0             6      2
# 7          0             7      1
# 8          0             8      2
# 9          0             9      1
# 10         0            10      2
# 11         0            11      0
# 12         0            12      1
# 13         0            13      0
# 14         0            14      1
# 15         0            15      1
# 16         0            16      0
# 17         0            17      0
# 18         0            18      1
# 19         0            19      1
# 20         0            20      1
# 21         0            21      1
# 22         0            22      1
# 23         0            23      1
# 24         0            24      1
# 25         0            25      0
# 26         0            26      1
# 27         0            27      0
# 28         0            28      1
# 29         0            29      1
# ..       ...           ...    ...
# 8      83565             8      0
# 9      83565             9      1
# 10     83565            10      0
# 11     83565            11      0
# 12     83565            12      2
# 13     83565            13      1
# 14     83565            14      0
# 15     83565            15      0
# 16     83565            16      0
# 17     83565            17      1
# 18     83565            18      0
# 19     83565            19      0
# 0      83566             0      1
# 1      83566             1      0
# 2      83566             2      0
# 0      83567             0      1
# 1      83567             1      2
# 2      83567             2      1
# 3      83567             3      2
# 4      83567             4      0
# 5      83567             5      1
# 6      83567             6      1
# 7      83567             7      0
# 8      83567             8      0
# 9      83567             9      0
# 10     83567            10      0
# 11     83567            11      1
# 12     83567            12      0
# 13     83567            13      1
# 14     83567            14      2
#
#                                                 query  \
# 0               Mistaken for your child's grandmother
# 1               Mistaken for your child's grandmother
# 2               Mistaken for your child's grandmother
# 3               Mistaken for your child's grandmother
# 4               Mistaken for your child's grandmother
# 5               Mistaken for your child's grandmother
# 6               Mistaken for your child's grandmother
# 7               Mistaken for your child's grandmother
# 8               Mistaken for your child's grandmother
# 9               Mistaken for your child's grandmother
# 10              Mistaken for your child's grandmother
# 11              Mistaken for your child's grandmother
# 12              Mistaken for your child's grandmother
# 13              Mistaken for your child's grandmother
# 14              Mistaken for your child's grandmother
# 15              Mistaken for your child's grandmother
# 16              Mistaken for your child's grandmother
# 17              Mistaken for your child's grandmother
# 18              Mistaken for your child's grandmother
# 19              Mistaken for your child's grandmother
# 20              Mistaken for your child's grandmother
# 21              Mistaken for your child's grandmother
# 22              Mistaken for your child's grandmother
# 23              Mistaken for your child's grandmother
# 24              Mistaken for your child's grandmother
# 25              Mistaken for your child's grandmother
# 26              Mistaken for your child's grandmother
# 27              Mistaken for your child's grandmother
# 28              Mistaken for your child's grandmother
# 29              Mistaken for your child's grandmother
# ..                                                ...
# 8     Nigella Lawson faces police drugs investigation
# 9     Nigella Lawson faces police drugs investigation
# 10    Nigella Lawson faces police drugs investigation
# 11    Nigella Lawson faces police drugs investigation
# 12    Nigella Lawson faces police drugs investigation
# 13    Nigella Lawson faces police drugs investigation
# 14    Nigella Lawson faces police drugs investigation
# 15    Nigella Lawson faces police drugs investigation
# 16    Nigella Lawson faces police drugs investigation
# 17    Nigella Lawson faces police drugs investigation
# 18    Nigella Lawson faces police drugs investigation
# 19    Nigella Lawson faces police drugs investigation
# 0                  Earthquake hits Dominican Republic
# 1                  Earthquake hits Dominican Republic
# 2                  Earthquake hits Dominican Republic
# 0   Suspect arrested in shooting of rapper Dolla a...
# 1   Suspect arrested in shooting of rapper Dolla a...
# 2   Suspect arrested in shooting of rapper Dolla a...
# 3   Suspect arrested in shooting of rapper Dolla a...
# 4   Suspect arrested in shooting of rapper Dolla a...
# 5   Suspect arrested in shooting of rapper Dolla a...
# 6   Suspect arrested in shooting of rapper Dolla a...
# 7   Suspect arrested in shooting of rapper Dolla a...
# 8   Suspect arrested in shooting of rapper Dolla a...
# 9   Suspect arrested in shooting of rapper Dolla a...
# 10  Suspect arrested in shooting of rapper Dolla a...
# 11  Suspect arrested in shooting of rapper Dolla a...
# 12  Suspect arrested in shooting of rapper Dolla a...
# 13  Suspect arrested in shooting of rapper Dolla a...
# 14  Suspect arrested in shooting of rapper Dolla a...
#
#                                              sentence  \
# 0                        -- i 'm 45 , and my son is 7
# 1   once in a while , i still get carded when i tr...
# 2   i was 38 when Dominican Republic Emergency Ope...
# 3   both incidents took place after i moved from A...
# 4   i thought about the incidents when i read a re...
# 5   the essay inspired me to post my case of mista...
# 6   had i let too many gray hairs escape my patrol...
# 7   but i have since learned about a convergence o...
# 8   first , experts say teenagers are having fewer...
# 9   " we believe evidence - based teen pregnancy p...
# 10          " we also believe in giving the kids hope
# 11  even with all the education in the world , if ...
# 12  and recent data shows that Sue Vannasing was o...
# 13                             it 's a national trend
# 14  according to preliminary data from the Cesar G...
# 15  black births to teens ages 15 to 17 have plumm...
# 16  still , black and London teenagers still have ...
# 17  the february report shows that the birth rate ...
# 18  if more young people are weighing their life o...
# 19  more children are being raised by their grandp...
# 20  Theirs data from 2009 , published in july , re...
# 21  about 5 % of black children are raised by a gr...
# 22  citing the impact of harsh economic times , th...
# 23  Gamal reports that the number of black grandpa...
# 24  the number of London grandparents becoming car...
# 25  according to Gamal , 53 % of grandparent careg...
# 26  " many of these children come to live with the...
# 27  " you 're entering your late fifties or sixtie...
# 28  " the project gives grandparent caretakers in ...
# 29  an average of 60 to 75 grandparent - led famil...
# ..                                                ...
# 8                       the couple divorced this year
# 9   at the trial , both sisters claimed to have se...
# 10  however , both testified that they had never s...
# 11  Illinois likewise said he had never seen his e...
# 12  Elisabetta Grillo told the court that Lawson h...
# 13  in her own testimony , Lawson confirmed she ha...
# 14               but she denied being a habitual user
# 15  Lawson , who was a prosecution witness , said ...
# 16  she slammed what she said was a sustained camp...
# 17  " over the three week trial the jury was faced...
# 18  " my experience as a witness was deeply distur...
# 19  when false claims about habitual drug use were...
# 0   -- an earthquake hit the CNN thursday , the Lo...
# 1   the 5.3 quake was centered in the south of the...
# 2   general Pasadena of the Dominican Republic Eme...
# 0   Los Angeles , California -- a Georgia man susp...
# 1   rap artist Dolla arrives at the Soul Train Mus...
# 2   Dolla , whose real name is Roderick Anthony Bu...
# 3   police later arrested Aubrey Louis Berry , 23 ...
# 4   no other details were given about Aubrey Louis...
# 5   Dolla , who was based in Atlanta , Georgia , w...
# 6   he caught the attention of multiplatinium R&B ...
# 7   the two collaborated on Dolla 's first single ...
# 8   another Dolla song , " Feelin ' Myself , " app...
# 9   " according to his MySpace page , Dolla was bo...
# 10  his twin sister died at birth due to complicat...
# 11  the family moved to Atlanta after Dolla 's fat...
# 12  Dolla began composing rhymes in elementary sch...
# 13  a source close to the record company said Doll...
# 14  funeral services , which will be held in Atlan...
#
#                                          true_summary
# 0   -- i 'm 45 , and my son is 7 once in a while ,...
# 1   -- i 'm 45 , and my son is 7 once in a while ,...
# 2   -- i 'm 45 , and my son is 7 once in a while ,...
# 3   -- i 'm 45 , and my son is 7 once in a while ,...
# 4   -- i 'm 45 , and my son is 7 once in a while ,...
# 5   -- i 'm 45 , and my son is 7 once in a while ,...
# 6   -- i 'm 45 , and my son is 7 once in a while ,...
# 7   -- i 'm 45 , and my son is 7 once in a while ,...
# 8   -- i 'm 45 , and my son is 7 once in a while ,...
# 9   -- i 'm 45 , and my son is 7 once in a while ,...
# 10  -- i 'm 45 , and my son is 7 once in a while ,...
# 11  -- i 'm 45 , and my son is 7 once in a while ,...
# 12  -- i 'm 45 , and my son is 7 once in a while ,...
# 13  -- i 'm 45 , and my son is 7 once in a while ,...
# 14  -- i 'm 45 , and my son is 7 once in a while ,...
# 15  -- i 'm 45 , and my son is 7 once in a while ,...
# 16  -- i 'm 45 , and my son is 7 once in a while ,...
# 17  -- i 'm 45 , and my son is 7 once in a while ,...
# 18  -- i 'm 45 , and my son is 7 once in a while ,...
# 19  -- i 'm 45 , and my son is 7 once in a while ,...
# 20  -- i 'm 45 , and my son is 7 once in a while ,...
# 21  -- i 'm 45 , and my son is 7 once in a while ,...
# 22  -- i 'm 45 , and my son is 7 once in a while ,...
# 23  -- i 'm 45 , and my son is 7 once in a while ,...
# 24  -- i 'm 45 , and my son is 7 once in a while ,...
# 25  -- i 'm 45 , and my son is 7 once in a while ,...
# 26  -- i 'm 45 , and my son is 7 once in a while ,...
# 27  -- i 'm 45 , and my son is 7 once in a while ,...
# 28  -- i 'm 45 , and my son is 7 once in a while ,...
# 29  -- i 'm 45 , and my son is 7 once in a while ,...
# ..                                                ...
# 8   Los Angeles -- Los Angeles Police police said ...
# 9   Los Angeles -- Los Angeles Police police said ...
# 10  Los Angeles -- Los Angeles Police police said ...
# 11  Los Angeles -- Los Angeles Police police said ...
# 12  Los Angeles -- Los Angeles Police police said ...
# 13  Los Angeles -- Los Angeles Police police said ...
# 14  Los Angeles -- Los Angeles Police police said ...
# 15  Los Angeles -- Los Angeles Police police said ...
# 16  Los Angeles -- Los Angeles Police police said ...
# 17  Los Angeles -- Los Angeles Police police said ...
# 18  Los Angeles -- Los Angeles Police police said ...
# 19  Los Angeles -- Los Angeles Police police said ...
# 0   -- an earthquake hit the CNN thursday , the Lo...
# 1   -- an earthquake hit the CNN thursday , the Lo...
# 2   -- an earthquake hit the CNN thursday , the Lo...
# 0   Los Angeles , California -- a Georgia man susp...
# 1   Los Angeles , California -- a Georgia man susp...
# 2   Los Angeles , California -- a Georgia man susp...
# 3   Los Angeles , California -- a Georgia man susp...
# 4   Los Angeles , California -- a Georgia man susp...
# 5   Los Angeles , California -- a Georgia man susp...
# 6   Los Angeles , California -- a Georgia man susp...
# 7   Los Angeles , California -- a Georgia man susp...
# 8   Los Angeles , California -- a Georgia man susp...
# 9   Los Angeles , California -- a Georgia man susp...
# 10  Los Angeles , California -- a Georgia man susp...
# 11  Los Angeles , California -- a Georgia man susp...
# 12  Los Angeles , California -- a Georgia man susp...
# 13  Los Angeles , California -- a Georgia man susp...
# 14  Los Angeles , California -- a Georgia man susp...
#
# [2541426 rows x 6 columns]
